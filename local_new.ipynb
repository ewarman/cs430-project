# %%
##########################
# CS 430 Final Project
# Emily Warman, Rachael Affenit
# Local Approach
##########################

import os
import copy
import itertools
import matplotlib.pyplot as plt
import math

# %%
# %matplotlib inline

def plot(points,lines):
    plt.scatter(*zip(*points))
    axes = plt.gca()
    #plot lines drawn
    for line in lines:
        if line[1]==0:
            plt.plot([line[0], line[0]],[0,len(points)], color='b', linestyle='-',linewidth=2)
        else:
            plt.plot([0,len(points)],[line[0],line[0]], color='b', linestyle='-', linewidth=2)
    plt.show()
    
#get all permutations of a list of possible lines
def get_combinations(lines):
    return itertools.combinations(lines,2)

#make a list of possible lines (range function that takes floats)
def drange(x, y, jump):
    r=[]
    while x < y:
        r.append(float(x))
        x += jump
    return r

#create lists of possible points (min x to max x, min y to max y)
#O(nlogn)
def get_all_possible(points):
    x_sort = sorted(points, key=lambda x: x[0])
    y_sort = sorted(points, key=lambda x: x[1])
    x_min = x_sort[0][0]
    x_max = x_sort[-1][0]
    y_min = y_sort[0][1]
    y_max = y_sort[-1][1]
    x = [0]*len(x_sort)
    y = [1]*len(y_sort)
    
    return (list(zip(drange(x_min+.5,x_max+.5,1),x))), (list(zip(drange(y_min+.5,y_max+.5,1),y)))
    #return drange(x_min+.5,x_max+.5,1)

def get_x_y_lines(lines):
    x_lines=[]
    y_lines=[]
    for line in lines:
        if line[1] == 0:
            x_lines.append(line[0])
        else:
            y_lines.append(line[1]) ## CHANGED 0 TO 1 ##
    return x_lines, y_lines

def split(box, line):
    left = []
    right = []
    print(line)
    
    #mark points left and right (or above and below) the line to be drawn
    for point in box:
        if point[0] < line[0] and point[0] > 0:
            left.append(point)
        elif point[0] > line[0] and point[0] > 0:
            right.append(point)
        elif point[1] < line[1] and point[1] > 0:
            left.append(point)
        elif point[1] > line[1] and point[1] > 0:
            right.append(point)
            
    return left, right

def collisions(pair,possible_line,points,lines):
    n=len(points)
    print(lines)
    
    # Check if both of pair exists in lines with possible line not in lines
    if (pair[0] in lines) and (pair[1] in lines) and (possible_line not in lines):
        lines.remove(pair[0])
        lines.remove(pair[1])
        lines.append(possible_line)
    
    else:
        return True, lines
        #print(pair[0],lines)
        #print(pair[1],lines)
    
    boxes = [points]
    for line in lines:
        new = []
        for box in boxes:
            b1, b2 = split(box, line)
            new.append(b1)
            new.append(b2)
        boxes = new
    if len(boxes) > 1:
        return True, lines
    else:
        return False, lines
    #x_lines,y_lines = get_x_y_lines(lines)
    
    #x_interval = [0]
    #x_interval.extend(x_lines)
    #x_interval.append(len(points)+1)
    
    #y_interval = [0]
    #y_interval.extend(y_lines)
    #y_interval.append(len(points)+1)
    
    #boxes=[]
    #print(x_interval,y_interval)
    
    #for point in points:
        #find box of point
        #print(point)
        
    #    x_box=0
    #    while (point[0]>=x_interval[x_box]) and (x_box<len(x_interval)):
    #        x_box+=1
    #        
    #    y_box=0
    #    while point[1]>=y_interval[y_box] and (y_box<len(y_interval)):
    #        y_box+=1
    #    
    #    box = (x_box-1,y_box-1)
    #    if box in boxes:
    #        return True, lines
    #    else:
    #        boxes.append(box)
    #return False, lines

def generate_possible_lines(points,lines_drawn):
    all_possible = get_all_possible(points)
    for line in lines_drawn:
        if line in all_possible:
            all_possible.remove(line)
    return(all_possible)

# %%
def solution(points, lines_drawn):
    LEN = len(lines_drawn)
    x = list(get_combinations(lines_drawn))
    #possible_lines = generate_possible_lines(points,lines_drawn)
    for pair in x:
        possible_lines = generate_possible_lines(points,lines_drawn)
        for possible_line in possible_lines:
            # If possible_line is not in lines drawn
            if collisions(pair, possible_line, points, lines_drawn) == False: 
                #print("NO COLLISIONS")
                if len(lines_drawn) == math.ceil(math.sqrt(len(points))*2)-2:
                    return(lines_drawn)
                else:
                    #print("CALL TO SOLUTION:",lines_drawn,possible_lines)
                    solution(points,lines_drawn)
                    
            # If possible line is in lines drawn
            else: 
                lines_drawn.insert(0,pair[1])
                lines_drawn.insert(0,pair[0])
                #lines_drawn.remove(possible_line)
            #print(lines_drawn)
    return(lines_drawn)

# %%
##########################
# Main Program: Import Data
##########################
#for filename in os.listdir(os.getcwd()+'/input'):
    
def read_file(filename):
    points = []
    with open('input/'+filename, 'r') as f:
        inpt = f.readlines()
        for point in inpt[1:]:
            point = point.split(' ')
            points.append(((int(point[0])),(int(point[1]))))
    return points

points = read_file('instance01.txt')
all_x_lines,all_y_lines=get_all_possible(points)
print(len(points))
ld = solution(points,all_x_lines)
print(ld)
plot(points,ld)
# Out:
# 10
# [(1.5, 0), (2.5, 0), (3.5, 0), (4.5, 0), (5.5, 0), (6.5, 0), (7.5, 0), (8.5, 0), (9.5, 0)]
# (3.5, 0)
# (4.5, 0)
# (4.5, 0)
# (5.5, 0)
# (5.5, 0)
# (5.5, 0)
# (5.5, 0)
# (6.5, 0)
# (6.5, 0)
# (6.5, 0)
# (6.5, 0)
# (6.5, 0)
# (6.5, 0)
# (6.5, 0)
# (6.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (7.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (8.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# (9.5, 0)
# [(1.5, 0), (2.5, 0), (3.5, 0), (4.5, 0), (5.5, 0), (6.5, 0), (7.5, 0), (8.5, 0), (9.5, 0)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-950cd9756583> in <module>()
#      16 all_x_lines,all_y_lines=get_all_possible(points)
#      17 print(len(points))
# ---> 18 ld = solution(points,all_x_lines)
#      19 print(ld)
#      20 plot(points,ld)
#
# <ipython-input-37-651ee34712b1> in solution(points, lines_drawn)
#       7         for possible_line in possible_lines:
#       8             # If possible_line is not in lines drawn
# ----> 9             if collisions(pair, possible_line, points, lines_drawn) == False:
#      10                 #print("NO COLLISIONS")
#      11                 if len(lines_drawn) == math.ceil(math.sqrt(len(points))*2)-2:
#
# <ipython-input-36-8fe4886a2648> in collisions(pair, possible_line, points, lines)
#      86         new = []
#      87         for box in boxes:
# ---> 88             b1, b2 = split(box, line)
#      89             new.append(b1)
#      90             new.append(b2)
#
# <ipython-input-36-8fe4886a2648> in split(box, line)
#      56     #mark points left and right (or above and below) the line to be drawn
#      57     for point in box:
# ---> 58         if point[0] < line[0] and point[0] > 0:
#      59             left.append(point)
#      60         elif point[0] > line[0] and point[0] > 0:
#
# TypeError: unorderable types: int() < tuple()

# %%
math.ceil(math.sqrt(20)*2)-2
# Out:
# 7
